# %%
from canon.T4.utils import load_image_and_masks, apply_mask
import cv2
from canon.utils.notebook_utils import show_image

# %%
img, masks = load_image_and_masks("antiga_1")

for i in range(3):
    result = apply_mask(img, masks[i])
    show_image(result)
# Out:
# C:\Projects\MC949-Visao-Computacional\data\T4
